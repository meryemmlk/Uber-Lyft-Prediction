# %%
import os
import json
from shapely.geometry import Polygon
from numpy import random
from shapely.geometry import Point
import pandas as pd

# libraries for UBER API
from uber_rides.session import Session
from uber_rides.client import UberRidesClient

# libraries for take the capture date
from datetime import datetime, timedelta
# libraries for capture data each 4 min
import threading

# %%
from uber_rides.session import Session
session = Session(server_token="TZ9aAN7GMzp49djfXoMil2HJ7XxCs0Zwo8EWXd88")

from uber_rides.client import UberRidesClient
client = UberRidesClient(session)

# %%
places = [
    { "name": "Georgia Tech",
  "location": [33.7762,-84.3895]},
  { "name": "Centennial Park",
  "location": [33.7603474,-84.3957012]},
  { "name": "Buckhead Bars",
  "location": [33.8439849,-84.3789694]},
  { "name": "Inman Park",
  "location": [33.7613676,-84.3623401]},
  { "name": "Stone Mountain",
  "location": [33.8053189,-84.1477255]},
  { "name": "Six Flags",
  "location": [33.7706408,-84.5537186]},
  { "name": "Statefarm Arena",
 "location": [33.7572891,-84.3963244]},
 { "name": "Zoo Atlanta",
 "location": [33.7327032,-84.3846396]},
 { "name": "Atlanta High Museum",
 "location": [33.7900632,-84.3877407]},
 { "name": "Fox Theater",
 "location": [33.7724591,-84.3879697]},
 { "name": "Virginia Highlands",
 "location": [33.7795027,-84.3757217]},
 { "name": "Shops at Buckhead",
 "location": [33.838031,-84.3821468]},
 { "name": "Emory University",
 "location": [33.7925239,-84.3261929]},
 { "name": "Georgia State University",
 "location": [33.7530724,-84.3874759]},
 { "name": "Spelman College",
 "location": [33.7463641,-84.4144874]},
 { "name": "Edgewood Bars",
 "location": [33.7544814,-84.3745674]},
  {"name": "Hartsfield Jackson Airport",
  "location": [33.6407282,-84.4277001]},
   {"name":"SunTrust Park",
   "location":[33.8908211,-84.4678309]},
   {"name":"Mercedes Benz Stadium",
   "location":[33.7554483,-84.400855]},
   {"name":"Lenox Square Mall",
    "location":[33.8462925,-84.3621419]},
   {"name":"Piedmont Park",
   "location":[33.7850856,-84.373803]}]

total_estimates = []
estimates = {}
#Global Learning Center GA TECH: 33.7762° N, 84.3895° W

for startplace in places:
    for endplace in places:
        if startplace["name"] != endplace["name"]:
            estimates = {}
            response = client.get_price_estimates(
                start_latitude= startplace["location"][0],
                start_longitude= startplace["location"][1],
                end_latitude= endplace["location"][0],
                end_longitude= endplace["location"][1]
            )

            estimate = response.json.get('prices')
            #print(estimate)
            #estimate10
            estimates["startplace"] = startplace["name"]
            estimates["endplace"] = endplace["name"]
            estimates["startgeometry"] = startplace["location"]
            estimates["endgeometry"] = endplace["location"]
            autotimeinit = datetime.now()
            autotime = autotimeinit.strftime('%H:%M')
            estimates["autotime"] = autotime
            autohour = autotimeinit.strftime('%H')
            autohour = autohour + ":00"
            estimates["time"] = autohour
            estimates["value"] = estimate
            # last_hour_date_time = datetime.now() - timedelta(hours = 1)
            # list_datetime_capture.append(last_hour_date_time.strftime('%Y-%m-%d %H:%M:%S'))
            total_estimates.append(estimates)
total_estimates
# Out:
# [{'startplace': 'Georgia Tech',
#   'endplace': 'Centennial Park',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7603474, -84.3957012],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.37,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 480,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.37,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 480,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.37,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 480,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.37,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 480,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.37,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 480,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.37,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 480,
#     'estimate': '$23-29',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Buckhead Bars',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.8439849, -84.3789694],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 6.72,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 1140,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 6.72,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 1140,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 6.72,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 1140,
#     'estimate': '$22-28',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 6.72,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 32.0,
#     'low_estimate': 25.0,
#     'duration': 1140,
#     'estimate': '$25-32',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 6.72,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 1140,
#     'estimate': '$35-44',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 6.72,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 59.0,
#     'low_estimate': 47.0,
#     'duration': 1140,
#     'estimate': '$47-59',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Inman Park',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7613676, -84.3623401],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.78,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.78,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.78,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 540,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.78,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 19.0,
#     'low_estimate': 15.0,
#     'duration': 540,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.78,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 25.0,
#     'low_estimate': 19.0,
#     'duration': 540,
#     'estimate': '$19-25',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.78,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 36.0,
#     'low_estimate': 28.0,
#     'duration': 540,
#     'estimate': '$28-36',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Stone Mountain',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.8053189, -84.1477255],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 17.52,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 27.0,
#     'low_estimate': 20.0,
#     'duration': 2040,
#     'estimate': '$20-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 17.52,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 27.0,
#     'low_estimate': 21.0,
#     'duration': 2040,
#     'estimate': '$21-27',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 17.52,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 57.0,
#     'low_estimate': 46.0,
#     'duration': 2040,
#     'estimate': '$46-57',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 17.52,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 60.0,
#     'low_estimate': 48.0,
#     'duration': 2040,
#     'estimate': '$48-60',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 17.52,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 85.0,
#     'low_estimate': 69.0,
#     'duration': 2040,
#     'estimate': '$69-85',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 17.52,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 110.0,
#     'low_estimate': 89.0,
#     'duration': 2040,
#     'estimate': '$89-110',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Six Flags',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7706408, -84.5537186],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 14.42,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 1320,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 14.42,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 1320,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 14.42,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 46.0,
#     'low_estimate': 37.0,
#     'duration': 1320,
#     'estimate': '$37-46',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 14.42,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 46.0,
#     'low_estimate': 37.0,
#     'duration': 1320,
#     'estimate': '$37-46',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 14.42,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 66.0,
#     'low_estimate': 53.0,
#     'duration': 1320,
#     'estimate': '$53-66',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 14.42,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 88.0,
#     'low_estimate': 71.0,
#     'duration': 1320,
#     'estimate': '$71-88',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Statefarm Arena',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7572891, -84.3963244],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.92,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.92,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.92,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 600,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.92,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 600,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.92,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 600,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.92,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 33.0,
#     'low_estimate': 26.0,
#     'duration': 600,
#     'estimate': '$26-33',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Zoo Atlanta',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7327032, -84.3846396],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.33,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 660,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.33,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 660,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.33,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 660,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.33,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 22.0,
#     'low_estimate': 17.0,
#     'duration': 660,
#     'estimate': '$17-22',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.33,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 30.0,
#     'low_estimate': 24.0,
#     'duration': 660,
#     'estimate': '$24-30',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.33,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 42.0,
#     'low_estimate': 34.0,
#     'duration': 660,
#     'estimate': '$34-42',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Atlanta High Museum',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7900632, -84.3877407],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.32,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 5.0,
#     'duration': 360,
#     'estimate': '$5-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.32,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 8.0,
#     'low_estimate': 6.0,
#     'duration': 360,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.32,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 360,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.32,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 15.0,
#     'low_estimate': 11.0,
#     'duration': 360,
#     'estimate': '$11-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.32,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 360,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.32,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 360,
#     'estimate': '$23-29',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Fox Theater',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7724591, -84.3879697],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 0.31,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 240,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 0.31,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 240,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 0.31,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 240,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 0.31,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 240,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 0.31,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 240,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 0.31,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 240,
#     'estimate': '$23-29',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Virginia Highlands',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7795027, -84.3757217],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.02,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 8.0,
#     'low_estimate': 5.0,
#     'duration': 360,
#     'estimate': '$5-7',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.02,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 8.0,
#     'low_estimate': 5.0,
#     'duration': 360,
#     'estimate': '$5-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.02,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 360,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.02,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 360,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.02,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 360,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.02,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 360,
#     'estimate': '$23-29',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Shops at Buckhead',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.838031, -84.3821468],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 6.32,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 13.0,
#     'low_estimate': 9.0,
#     'duration': 1140,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 6.32,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 1140,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 6.32,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 27.0,
#     'low_estimate': 21.0,
#     'duration': 1140,
#     'estimate': '$21-27',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 6.32,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 31.0,
#     'low_estimate': 25.0,
#     'duration': 1140,
#     'estimate': '$25-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 6.32,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 42.0,
#     'low_estimate': 34.0,
#     'duration': 1140,
#     'estimate': '$34-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 6.32,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 57.0,
#     'low_estimate': 46.0,
#     'duration': 1140,
#     'estimate': '$46-57',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Emory University',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7925239, -84.3261929],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.67,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 7.0,
#     'duration': 1020,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.67,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 1020,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.67,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 1020,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.67,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 1020,
#     'estimate': '$22-28',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.67,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 37.0,
#     'low_estimate': 29.0,
#     'duration': 1020,
#     'estimate': '$29-37',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.67,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 50.0,
#     'low_estimate': 40.0,
#     'duration': 1020,
#     'estimate': '$40-50',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Georgia State University',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7530724, -84.3874759],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.05,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.05,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.05,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 600,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.05,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 600,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.05,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 26.0,
#     'low_estimate': 20.0,
#     'duration': 600,
#     'estimate': '$20-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.05,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 37.0,
#     'low_estimate': 30.0,
#     'duration': 600,
#     'estimate': '$30-37',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Spelman College',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7463641, -84.4144874],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.72,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.72,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 600,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.72,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 21.0,
#     'low_estimate': 16.0,
#     'duration': 600,
#     'estimate': '$16-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.72,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 600,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.72,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 600,
#     'estimate': '$24-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.72,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 43.0,
#     'low_estimate': 35.0,
#     'duration': 600,
#     'estimate': '$35-43',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Edgewood Bars',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7544814, -84.3745674],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.39,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.39,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.39,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 15.0,
#     'low_estimate': 11.0,
#     'duration': 540,
#     'estimate': '$11-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.39,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 540,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.39,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 540,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.39,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 34.0,
#     'low_estimate': 27.0,
#     'duration': 540,
#     'estimate': '$27-34',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Hartsfield Jackson Airport',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.6407282, -84.4277001],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 12.96,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 1320,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 12.96,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 1320,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 12.96,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 43.0,
#     'low_estimate': 34.0,
#     'duration': 1320,
#     'estimate': '$34-43',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 12.96,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 43.0,
#     'low_estimate': 35.0,
#     'duration': 1320,
#     'estimate': '$35-43',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 12.96,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 62.0,
#     'low_estimate': 49.0,
#     'duration': 1320,
#     'estimate': '$49-62',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 12.96,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 82.0,
#     'low_estimate': 66.0,
#     'duration': 1320,
#     'estimate': '$66-82',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'SunTrust Park',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.8908211, -84.4678309],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 11.21,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 18.0,
#     'low_estimate': 13.0,
#     'duration': 960,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 11.21,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 960,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 11.21,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 37.0,
#     'low_estimate': 30.0,
#     'duration': 960,
#     'estimate': '$30-37',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 11.21,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 37.0,
#     'low_estimate': 29.0,
#     'duration': 960,
#     'estimate': '$29-37',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 11.21,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 52.0,
#     'low_estimate': 42.0,
#     'duration': 960,
#     'estimate': '$42-52',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 11.21,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 71.0,
#     'low_estimate': 57.0,
#     'duration': 960,
#     'estimate': '$57-71',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Mercedes Benz Stadium',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7554483, -84.400855],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.83,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.83,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.83,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 600,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.83,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 600,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.83,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 600,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.83,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 33.0,
#     'low_estimate': 26.0,
#     'duration': 600,
#     'estimate': '$26-33',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Lenox Square Mall',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.8462925, -84.3621419],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 7.26,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 1080,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 7.26,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 1080,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 7.26,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 1080,
#     'estimate': '$23-29',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 7.26,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 32.0,
#     'low_estimate': 25.0,
#     'duration': 1080,
#     'estimate': '$25-32',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 7.26,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 1080,
#     'estimate': '$35-44',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 7.26,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 60.0,
#     'low_estimate': 48.0,
#     'duration': 1080,
#     'estimate': '$48-60',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Georgia Tech',
#   'endplace': 'Piedmont Park',
#   'startgeometry': [33.7762, -84.3895],
#   'endgeometry': [33.7850856, -84.373803],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.54,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.54,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.54,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 540,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.54,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 540,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.54,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 21.0,
#     'low_estimate': 17.0,
#     'duration': 540,
#     'estimate': '$17-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.54,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 540,
#     'estimate': '$24-31',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Centennial Park',
#   'endplace': 'Georgia Tech',
#   'startgeometry': [33.7603474, -84.3957012],
#   'endgeometry': [33.7762, -84.3895],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.68,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.68,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 10.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.68,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 540,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.68,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 540,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.68,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 22.0,
#     'low_estimate': 17.0,
#     'duration': 540,
#     'estimate': '$17-22',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.68,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 31.0,
#     'low_estimate': 25.0,
#     'duration': 540,
#     'estimate': '$25-31',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Centennial Park',
#   'endplace': 'Buckhead Bars',
#   'startgeometry': [33.7603474, -84.3957012],
#   'endgeometry': [33.8439849, -84.3789694],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 8.4,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 15.0,
#     'low_estimate': 10.0,
#     'duration': 1320,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 8.4,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 1320,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 8.4,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 33.0,
#     'low_estimate': 26.0,
#     'duration': 1320,
#     'estimate': '$26-33',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 8.4,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 37.0,
#     'low_estimate': 29.0,
#     'duration': 1320,
#     'estimate': '$29-37',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 8.4,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 51.0,
#     'low_estimate': 41.0,
#     'duration': 1320,
#     'estimate': '$41-51',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 8.4,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 68.0,
#     'low_estimate': 54.0,
#     'duration': 1320,
#     'estimate': '$54-68',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Centennial Park',
#   'endplace': 'Inman Park',
#   'startgeometry': [33.7603474, -84.3957012],
#   'endgeometry': [33.7613676, -84.3623401],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.77,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.77,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.77,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 16.0,
#     'low_estimate': 13.0,
#     'duration': 600,
#     'estimate': '$13-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.77,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 19.0,
#     'low_estimate': 15.0,
#     'duration': 600,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.77,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 25.0,
#     'low_estimate': 20.0,
#     'duration': 600,
#     'estimate': '$20-25',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.77,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 36.0,
#     'low_estimate': 29.0,
#     'duration': 600,
#     'estimate': '$29-36',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Centennial Park',
#   'endplace': 'Stone Mountain',
#   'startgeometry': [33.7603474, -84.3957012],
#   'endgeometry': [33.8053189, -84.1477255],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 19.17,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 29.0,
#     'low_estimate': 22.0,
#     'duration': 2220,
#     'estimate': '$22-28',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 19.17,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 30.0,
#     'low_estimate': 23.0,
#     'duration': 2220,
#     'estimate': '$23-30',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 19.17,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 62.0,
#     'low_estimate': 50.0,
#     'duration': 2220,
#     'estimate': '$50-62',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 19.17,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 64.0,
#     'low_estimate': 51.0,
#     'duration': 2220,
#     'estimate': '$51-64',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 19.17,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 91.0,
#     'low_estimate': 74.0,
#     'duration': 2220,
#     'estimate': '$74-91',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 19.17,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 118.0,
#     'low_estimate': 96.0,
#     'duration': 2220,
#     'estimate': '$96-118',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Centennial Park',
#   'endplace': 'Six Flags',
#   'startgeometry': [33.7603474, -84.3957012],
#   'endgeometry': [33.7706408, -84.5537186],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 12.63,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 1320,
#     'estimate': '$13-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 12.63,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 1320,
#     'estimate': '$14-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 12.63,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 42.0,
#     'low_estimate': 34.0,
#     'duration': 1320,
#     'estimate': '$34-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 12.63,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 1320,
#     'estimate': '$35-44',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 12.63,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 62.0,
#     'low_estimate': 49.0,
#     'duration': 1320,
#     'estimate': '$49-62',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 12.63,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 82.0,
#     'low_estimate': 66.0,
#     'duration': 1320,
#     'estimate': '$66-82',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Centennial Park',
#   'endplace': 'Statefarm Arena',
#   'startgeometry': [33.7603474, -84.3957012],
#   'endgeometry': [33.7572891, -84.3963244],
#   'autotime': '09:14',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 0.73,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 300,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 0.73,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 300,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 0.73,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
# ...
#    {'localized_display_name': 'Select',
#     'distance': 5.22,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 30.0,
#     'low_estimate': 24.0,
#     'duration': 1200,
#     'estimate': '$24-30',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 5.22,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 41.0,
#     'low_estimate': 32.0,
#     'duration': 1200,
#     'estimate': '$32-41',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 5.22,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 54.0,
#     'low_estimate': 44.0,
#     'duration': 1200,
#     'estimate': '$44-54',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Emory University',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.7925239, -84.3261929],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.78,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 1020,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.78,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 1020,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.78,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 21.0,
#     'low_estimate': 16.0,
#     'duration': 1020,
#     'estimate': '$16-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.78,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 26.0,
#     'low_estimate': 20.0,
#     'duration': 1020,
#     'estimate': '$20-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.78,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 34.0,
#     'low_estimate': 27.0,
#     'duration': 1020,
#     'estimate': '$27-34',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.78,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 47.0,
#     'low_estimate': 37.0,
#     'duration': 1020,
#     'estimate': '$37-47',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Georgia State University',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.7530724, -84.3874759],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.37,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 960,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.37,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 960,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.37,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 960,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.37,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 25.0,
#     'low_estimate': 19.0,
#     'duration': 960,
#     'estimate': '$19-25',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.37,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 33.0,
#     'low_estimate': 26.0,
#     'duration': 960,
#     'estimate': '$26-33',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.37,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 960,
#     'estimate': '$35-44',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Spelman College',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.7463641, -84.4144874],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 6.14,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 11.0,
#     'low_estimate': 7.0,
#     'duration': 1080,
#     'estimate': '$7-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 6.14,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 1080,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 6.14,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 27.0,
#     'low_estimate': 21.0,
#     'duration': 1080,
#     'estimate': '$21-27',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 6.14,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 30.0,
#     'low_estimate': 24.0,
#     'duration': 1080,
#     'estimate': '$24-30',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 6.14,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 41.0,
#     'low_estimate': 33.0,
#     'duration': 1080,
#     'estimate': '$33-41',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 6.14,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 55.0,
#     'low_estimate': 44.0,
#     'duration': 1080,
#     'estimate': '$44-55',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Edgewood Bars',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.7544814, -84.3745674],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.13,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 8.0,
#     'low_estimate': 5.0,
#     'duration': 720,
#     'estimate': '$5-7',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.13,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 720,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.13,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 720,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.13,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 720,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.13,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 26.0,
#     'low_estimate': 20.0,
#     'duration': 720,
#     'estimate': '$20-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.13,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 37.0,
#     'low_estimate': 29.0,
#     'duration': 720,
#     'estimate': '$29-37',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Hartsfield Jackson Airport',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.6407282, -84.4277001],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 14.38,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 23.0,
#     'low_estimate': 17.0,
#     'duration': 1680,
#     'estimate': '$17-22',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 14.38,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 1680,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 14.38,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 48.0,
#     'low_estimate': 39.0,
#     'duration': 1680,
#     'estimate': '$39-48',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 14.38,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 51.0,
#     'low_estimate': 40.0,
#     'duration': 1680,
#     'estimate': '$40-51',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 14.38,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 72.0,
#     'low_estimate': 58.0,
#     'duration': 1680,
#     'estimate': '$58-72',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 14.38,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 94.0,
#     'low_estimate': 76.0,
#     'duration': 1680,
#     'estimate': '$76-94',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'SunTrust Park',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.8908211, -84.4678309],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 11.86,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 1260,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 11.86,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 21.0,
#     'low_estimate': 16.0,
#     'duration': 1260,
#     'estimate': '$16-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 11.86,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 40.0,
#     'low_estimate': 32.0,
#     'duration': 1260,
#     'estimate': '$32-40',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 11.86,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 41.0,
#     'low_estimate': 33.0,
#     'duration': 1260,
#     'estimate': '$33-41',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 11.86,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 58.0,
#     'low_estimate': 46.0,
#     'duration': 1260,
#     'estimate': '$46-58',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 11.86,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 77.0,
#     'low_estimate': 62.0,
#     'duration': 1260,
#     'estimate': '$62-77',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Mercedes Benz Stadium',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.7554483, -84.400855],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.36,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 12.0,
#     'low_estimate': 8.0,
#     'duration': 1080,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.36,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 9.0,
#     'duration': 1080,
#     'estimate': '$9-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.36,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 21.0,
#     'low_estimate': 16.0,
#     'duration': 1080,
#     'estimate': '$16-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.36,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 26.0,
#     'low_estimate': 21.0,
#     'duration': 1080,
#     'estimate': '$21-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.36,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 35.0,
#     'low_estimate': 27.0,
#     'duration': 1080,
#     'estimate': '$27-35',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.36,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 47.0,
#     'low_estimate': 37.0,
#     'duration': 1080,
#     'estimate': '$37-47',
#     'currency_code': 'USD'}]},
#  {'startplace': 'Piedmont Park',
#   'endplace': 'Lenox Square Mall',
#   'startgeometry': [33.7850856, -84.373803],
#   'endgeometry': [33.8462925, -84.3621419],
#   'autotime': '09:20',
#   'time': '09:00',
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 5.72,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 14.0,
#     'low_estimate': 9.0,
#     'duration': 1200,
#     'estimate': '$9-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 5.72,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 1200,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 5.72,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 26.0,
#     'low_estimate': 21.0,
#     'duration': 1200,
#     'estimate': '$21-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 5.72,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 31.0,
#     'low_estimate': 25.0,
#     'duration': 1200,
#     'estimate': '$25-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 5.72,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 42.0,
#     'low_estimate': 34.0,
#     'duration': 1200,
#     'estimate': '$34-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 5.72,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 57.0,
#     'low_estimate': 45.0,
#     'duration': 1200,
#     'estimate': '$45-57',
#     'currency_code': 'USD'}]}]

# %%
len(total_estimates)
# Out:
# 441

# %%
import json
with open('outfile.json', 'w') as outfile:
    json.dump(total_estimates, outfile)

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Define our uberPrices table
class UberPricesExtended2(Base):
    __tablename__ = 'uberPricesextended2'
    id = Column(Integer, primary_key=True)
    startplace = Column(String)
    endplace = Column(String)
    slat = Column(Integer)
    slon = Column(Integer)
    elat = Column(Integer)
    elon = Column(Integer)
    dist = Column(Integer)
    display_name = Column(String)
    product_id = Column(String)
    duration = Column(Integer)
    estimate = Column(String)
    high_estimate = Column(Integer)
    low_estimate = Column(Integer)
    autotime = Column(String)
    time = Column(String)

# %%
# Right now, this table only exists in python and not in the actual database
# Base.metadata.tables

# %%
# Create our database engine
engine = create_engine('sqlite:///UberPricesExtended2.sqlite')

# %%
Base.metadata.create_all(engine)

# %%
# The ORM’s “handle” to the database is the Session.
from sqlalchemy.orm import Session
session = Session(engine)

# %%
# Note that adding to the session does not update the table. It queues up those queries.
for values in total_estimates:
    for value in values["value"]:
        session.add(UberPricesExtended2(startplace=values["startplace"], endplace=values["endplace"],
                                       slat=values["startgeometry"][0], slon=values["startgeometry"][1], 
                                       elat=values["endgeometry"][0], elon=values["endgeometry"][1],
                               dist=value["distance"], display_name = value["display_name"], product_id = value["product_id"], 
                               duration = value["duration"], estimate = value["estimate"],
                               high_estimate = value["high_estimate"], low_estimate = value["low_estimate"],
                               autotime=values["autotime"], time=values["time"]
                              ))

# %%
# commit() flushes whatever remaining changes remain to the database, and commits the transaction.
session.commit()
