# %%
import os
import json
# from shapely.geometry import Polygon
from numpy import random
# from shapely.geometry import Point
import pandas as pd

# libraries for UBER API
from uber_rides.session import Session
from uber_rides.client import UberRidesClient

# libraries for take the capture date
from datetime import datetime, timedelta

# libraries for capture data each 4 min
import threading
import pprint

# %%
places = [
  { "name": "Centennial Park",
  "location": [33.7603474,-84.3957012]},
  { "name": "Buckhead Bars",
  "location": [33.8439849,-84.3789694]},
  { "name": "Inman Park",
  "location": [33.7613676,-84.3623401]},
  { "name": "Stone Mountain",
  "location": [33.8053189,-84.1477255]},
  { "name": "Six Flags",
  "location": [33.7706408,-84.5537186]},
  { "name": "Statefarm Arena",
 "location": [33.7572891,-84.3963244]},
 { "name": "Zoo Atlanta",
 "location": [33.7327032,-84.3846396]},
 { "name": "Atlanta High Museum",
 "location": [33.7900632,-84.3877407]},
 { "name": "Fox Theater",
 "location": [33.7724591,-84.3879697]},
 { "name": "Virginia Highlands",
 "location": [33.7795027,-84.3757217]},
 { "name": "Shops at Buckhead",
 "location": [33.838031,-84.3821468]},
 { "name": "Emory University",
 "location": [33.7925239,-84.3261929]},
 { "name": "Georgia State University",
 "location": [33.7530724,-84.3874759]},
 { "name": "Spelman College",
 "location": [33.7463641,-84.4144874]},
 { "name": "Edgewood Bars",
 "location": [33.7544814,-84.3745674]},
  {"name": "Hartsfield Jackson Airport",
  "location": [33.6407282,-84.4277001]},
   {"name":"SunTrust Park",
   "location":[33.8908211,-84.4678309]},
   {"name":"Mercedes Benz Stadium",
   "location":[33.7554483,-84.400855]},
   {"name":"Lenox Square Mall",
    "location":[33.8462925,-84.3621419]},
   {"name":"Piedmont Park",
   "location":[33.7850856,-84.373803]}]

# %%
total_closeby = []

# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json


# Google API Key
#from config import gkey


gkey = "AIzaSyCT1kl3HMfU0oOvSt4vTgysiQW1LXXl4Bw"

Address = "6000 N Terminal Pkwy, Atlanta, GA 30320"
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

total_closeby = []

for place in places:
    print(place["name"])
    print(place["location"][0],place["location"][1])
    params = {
        "location": "{}, {}".format(place["location"][0],place["location"][1]),  # address lat and long,
        "rankby": "distance",
        "type": "restaurant",
        "key": gkey,
    }

    # "Hello, {}. You are {}.".format(name, age)
    # "location": "33.8053189, -84.1477255"
    response = requests.get(base_url,params=params).json()
    # print(response['results'])
    
    closeby_info = {}
    place_closeby = []
    
    results = response['results']
    maxrange = len(results)
    if 10 < maxrange:
        maxrange = 10
    
    for i in range(maxrange):
        result = results[i]
        closeby_info["mainplace"] = place["name"]
        closeby_info["mlat"] = float(place["location"][0])
        closeby_info["mlon"] = float(place["location"][1])
        closeby_info["name"] = result["name"]
        closeby_info["lat"] = float(result["geometry"]["location"]["lat"])
        closeby_info["lon"] = float(result["geometry"]["location"]["lng"])
        closeby_info["vicinity"] = result["vicinity"]
        try:
            closeby_info["rating"] = result["rating"]
        except:
            closeby_info["rating"] = 0
        place_closeby.append(closeby_info)
        total_closeby.append(closeby_info)
    # pprint.pprint(place_closeby)
# Out:
# Centennial Park
# 33.7603474 -84.3957012
# Buckhead Bars
# 33.8439849 -84.3789694
# Inman Park
# 33.7613676 -84.3623401
# Stone Mountain
# 33.8053189 -84.1477255
# Six Flags
# 33.7706408 -84.5537186
# Statefarm Arena
# 33.7572891 -84.3963244
# Zoo Atlanta
# 33.7327032 -84.3846396
# Atlanta High Museum
# 33.7900632 -84.3877407
# Fox Theater
# 33.7724591 -84.3879697
# Virginia Highlands
# 33.7795027 -84.3757217
# Shops at Buckhead
# 33.838031 -84.3821468
# Emory University
# 33.7925239 -84.3261929
# Georgia State University
# 33.7530724 -84.3874759
# Spelman College
# 33.7463641 -84.4144874
# Edgewood Bars
# 33.7544814 -84.3745674
# Hartsfield Jackson Airport
# 33.6407282 -84.4277001
# SunTrust Park
# 33.8908211 -84.4678309
# Mercedes Benz Stadium
# 33.7554483 -84.400855
# Lenox Square Mall
# 33.8462925 -84.3621419
# Piedmont Park
# 33.7850856 -84.373803

# %%
#response

# %%
pprint.pprint(total_closeby)
# Out:
# [{'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.7617779,
#   'lon': -84.3950864,
#   'mainplace': 'Centennial Park',
#   'mlat': 33.7603474,
#   'mlon': -84.3957012,
#   'name': 'Baja Fresh Mexican Grill',
#   'rating': 3.7,
#   'vicinity': '250 Park Avenue West Northwest, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.8417729,
#   'lon': -84.3785844,
#   'mainplace': 'Buckhead Bars',
#   'mlat': 33.8439849,
#   'mlon': -84.3789694,
#   'name': "Domino's Pizza",
#   'rating': 3.4,
#   'vicinity': '3175 Roswell Road Northeast Ste B, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.75856489999999,
#   'lon': -84.36382259999999,
#   'mainplace': 'Inman Park',
#   'mlat': 33.7613676,
#   'mlon': -84.3623401,
#   'name': 'Kevin Rathbun Steak',
#   'rating': 4.6,
#   'vicinity': '154 Krog Street Northeast #200, Atlanta'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7931154,
#   'lon': -84.15301029999999,
#   'mainplace': 'Stone Mountain',
#   'mlat': 33.8053189,
#   'mlon': -84.1477255,
#   'name': 'Zakia Shop',
#   'rating': 5,
#   'vicinity': '648 Pennybrook Lane, Stone Mountain'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.7698502,
#   'lon': -84.54921750000001,
#   'mainplace': 'Six Flags',
#   'mlat': 33.7706408,
#   'mlon': -84.5537186,
#   'name': "Dee Jay's Diner",
#   'rating': 2.5,
#   'vicinity': 'Austell'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.757941,
#   'lon': -84.394769,
#   'mainplace': 'Statefarm Arena',
#   'mlat': 33.7572891,
#   'mlon': -84.3963244,
#   'name': 'Chick-fil-A',
#   'rating': 3.4,
#   'vicinity': '1 Cnn Ctr NW, Ste 224, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7255493,
#   'lon': -84.3770894,
#   'mainplace': 'Zoo Atlanta',
#   'mlat': 33.7327032,
#   'mlon': -84.3846396,
#   'name': 'Patria Cocina',
#   'rating': 4.3,
#   'vicinity': '1039 Grant Street Southeast, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7930976,
#   'lon': -84.3880539,
#   'mainplace': 'Atlanta High Museum',
#   'mlat': 33.7900632,
#   'mlon': -84.3877407,
#   'name': 'Xhibit Studio Kitchen and Bar',
#   'rating': 5,
#   'vicinity': '1414 West Peachtree Street Northwest, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7735591,
#   'lon': -84.386393,
#   'mainplace': 'Fox Theater',
#   'mlat': 33.7724591,
#   'mlon': -84.3879697,
#   'name': 'Pacific Grill',
#   'rating': 4.5,
#   'vicinity': '675 West Peachtree Street Northwest #6, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.7815224,
#   'lon': -84.38083329999999,
#   'mainplace': 'Virginia Highlands',
#   'mlat': 33.7795027,
#   'mlon': -84.3757217,
#   'name': 'Ten Atlanta',
#   'rating': 4.1,
#   'vicinity': '990 Piedmont Avenue Northeast, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.83896240000001,
#   'lon': -84.3807978,
#   'mainplace': 'Shops at Buckhead',
#   'mlat': 33.838031,
#   'mlon': -84.3821468,
#   'name': 'Seasons 52',
#   'rating': 4.5,
#   'vicinity': '3050 Peachtree Road Northwest, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7879509,
#   'lon': -84.32628419999999,
#   'mainplace': 'Emory University',
#   'mlat': 33.7925239,
#   'mlon': -84.3261929,
#   'name': "Lucky's Burger & Brew Emory Village",
#   'rating': 4.3,
#   'vicinity': '1569 North Decatur Road, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7542409,
#   'lon': -84.38853399999999,
#   'mainplace': 'Georgia State University',
#   'mlat': 33.7530724,
#   'mlon': -84.3874759,
#   'name': 'Roly Poly',
#   'rating': 4.2,
#   'vicinity': '8 Park Place South SE, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7409361,
#   'lon': -84.41722999999999,
#   'mainplace': 'Spelman College',
#   'mlat': 33.7463641,
#   'mlon': -84.4144874,
#   'name': 'Taste of Tropical',
#   'rating': 4.2,
#   'vicinity': '530 Joseph E Lowery Boulevard Southwest, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.7542333,
#   'lon': -84.37291859999999,
#   'mainplace': 'Edgewood Bars',
#   'mlat': 33.7544814,
#   'mlon': -84.3745674,
#   'name': 'MOTHER Bar + Kitchen',
#   'rating': 4.2,
#   'vicinity': '447 Edgewood Avenue Southeast, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.6407365,
#   'lon': -84.4293112,
#   'mainplace': 'Hartsfield Jackson Airport',
#   'mlat': 33.6407282,
#   'mlon': -84.4277001,
#   'name': 'Popeyes Louisiana Kitchen',
#   'rating': 3.9,
#   'vicinity': 'Atrium, 6000 North Terminal Parkway, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.8895234,
#   'lon': -84.4692469,
#   'mainplace': 'SunTrust Park',
#   'mlat': 33.8908211,
#   'mlon': -84.4678309,
#   'name': 'Yard House',
#   'rating': 4.2,
#   'vicinity': '825 Battery Avenue Southeast #320, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.7517828,
#   'lon': -84.39925989999999,
#   'mainplace': 'Mercedes Benz Stadium',
#   'mlat': 33.7554483,
#   'mlon': -84.400855,
#   'name': 'Fellaship',
#   'rating': 5,
#   'vicinity': '110 Centennial Olympic Park Drive Suite 102-104, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.8454713,
#   'lon': -84.3612545,
#   'mainplace': 'Lenox Square Mall',
#   'mlat': 33.8462925,
#   'mlon': -84.3621419,
#   'name': 'Sarku Japan Sushi Bar',
#   'rating': 3.9,
#   'vicinity': '3393 Peachtree Road, NE., Space#K-113, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'},
#  {'lat': 33.781115,
#   'lon': -84.36873399999999,
#   'mainplace': 'Piedmont Park',
#   'mlat': 33.7850856,
#   'mlon': -84.373803,
#   'name': "Woody's CheeseSteaks",
#   'rating': 4.4,
#   'vicinity': '981 Monroe Drive Northeast, Atlanta'}]

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Define our uberPrices table
class ClosebyRestaurants(Base):
    __tablename__ = 'closebyRestaurants'
    id = Column(Integer, primary_key=True)
    place = Column(String)
    mlat = Column(Integer)
    mlon = Column(Integer)
    lat = Column(Integer)
    lon = Column(Integer)
    name = Column(String)
    rating = Column(Integer)
    vicinity = Column(String)

# %%
# Create our database engine
engine = create_engine('sqlite:///ClosebyRestaurants.sqlite')

# %%
Base.metadata.create_all(engine)

# %%
# The ORM’s “handle” to the database is the Session.
from sqlalchemy.orm import Session
session = Session(engine)

# %%
# Note that adding to the session does not update the table. It queues up those queries.
maxrange = len(results)

if 10 < maxrange:
    maxrange = 10
for i in range(maxrange):
    value = total_closeby[i]
    try:
        rating = value["rating"]
    except:
        value["rating"] = 0
    session.add(ClosebyRestaurants(place=value["mainplace"], 
                              mlat=value["mlat"], 
                                mlon=value["mlon"], 
                                lat = value["lat"],
                                lon = value["lon"],
                                name=value["name"], 
                                rating = value["rating"], 
                                vicinity = value["vicinity"]
                              ))

# %%
# commit() flushes whatever remaining changes remain to the database, and commits the transaction.
session.commit()

# %%
results = response["results"]
results

# %%
results[0]

# %%
results[1]

# %%
results[0]["geometry"]

# %%
results[0]["rating"]

# %%
total_closeby[0]["closeby"][i]["geometry"]["location"]["lat"]

# %%
total_closeby[0]["closeby"]

# %%
total_closeby

# %%
Base.metadata.drop_all

# %%
maxrange = len(results)
maxrange
